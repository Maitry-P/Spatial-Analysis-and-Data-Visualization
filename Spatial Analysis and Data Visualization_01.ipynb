# %%
print(" SUBJECT: URPL-GP-1620 'Spatial Analysis and Data Visualization Fall’ 19")
# Out:
#  SUBJECT: URPL-GP-1620 'Spatial Analysis and Data Visualization Fall’ 19

# %%
print("Monday; 11/04/2019")
# Out:
# Monday; 11/04/2019

# %%
print("Name- Pujara, Maitri")
# Out:
# Name- Pujara, Maitri

# %%
print(" Hello Everyone, Here I have analyzed 'Real Estate Data and try to make meaningful output from it ")
# Out:
#  Hello Everyone, Here I have analyzed 'Real Estate Data and try to make meaningful output from it

# %% [markdown]
# Step-2
# Pre-installed common libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step-7 Finding Minimum Area of House

# %%
print(" The smallest space for housing is " + str(data.sq__ft.min()))
# Out:
#  The smallest space for housing is 0

# %% [markdown]
# Step-8 Finding Maximum Price of House

# %%
print(" The highest price for housing is " + str(data.price.max()))
# Out:
#  The highest price for housing is 884790

# %% [markdown]
# Step-9 Finding Minimum Price of House

# %%
print(" The lowest price for housing is " + str(data.price.min()))
# Out:
#  The lowest price for housing is 1551

# %% [markdown]
# Step-10

# %%
RealEstate = pd.read_csv('RealEstate_CSV.csv')

# %% [markdown]
# Step-11 Getting our data

# %%
https://drive.google.com/file/d/16xCgGhliz-RJO5Nf7W0cSv0_oKS94cm_/view?usp=sharing
uc?export=download&id

# %% [markdown]
# uc?export=download&id

# %%
pd.read_csv('https://drive.google.com/uc?export=download&id=16xCgGhliz-RJO5Nf7W0cSv0_oKS94cm_')
# Out:
#                   street             city    zip  ...   price   latitude   longitude
# 0           3526 HIGH ST       SACRAMENTO  95838  ...   59222  38.631913 -121.434879
# 1            51 OMAHA CT       SACRAMENTO  95823  ...   68212  38.478902 -121.431028
# 2         2796 BRANCH ST       SACRAMENTO  95815  ...   68880  38.618305 -121.443839
# 3       2805 JANETTE WAY       SACRAMENTO  95815  ...   69307  38.616835 -121.439146
# 4        6001 MCMAHON DR       SACRAMENTO  95824  ...   81900  38.519470 -121.435768
# ..                   ...              ...    ...  ...     ...        ...         ...
# 926   9169 GARLINGTON CT       SACRAMENTO  95829  ...  232425  38.457679 -121.359620
# 927      6932 RUSKUT WAY       SACRAMENTO  95823  ...  234000  38.499893 -121.458890
# 928    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610  ...  235000  38.708824 -121.256803
# 929     8304 RED FOX WAY        ELK GROVE  95758  ...  235301  38.417000 -121.397424
# ...

# %% [markdown]
# Step-12 Importing CSV files and Previewing dataframes

# %%
Real_Estate_raw = pd.read_csv('https://drive.google.com/uc?export=download&id=16xCgGhliz-RJO5Nf7W0cSv0_oKS94cm_')
Real_Estate_raw.head()
# Out:
#              street        city    zip  ...  price   latitude   longitude
# 0      3526 HIGH ST  SACRAMENTO  95838  ...  59222  38.631913 -121.434879
# 1       51 OMAHA CT  SACRAMENTO  95823  ...  68212  38.478902 -121.431028
# 2    2796 BRANCH ST  SACRAMENTO  95815  ...  68880  38.618305 -121.443839
# 3  2805 JANETTE WAY  SACRAMENTO  95815  ...  69307  38.616835 -121.439146
# 4   6001 MCMAHON DR  SACRAMENTO  95824  ...  81900  38.519470 -121.435768
#
# [5 rows x 12 columns]

# %%
Real_Estate_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 931 entries, 0 to 930
# Data columns (total 12 columns):
# street       931 non-null object
# city         931 non-null object
# zip          931 non-null int64
# state        931 non-null object
# beds         931 non-null int64
# baths        931 non-null int64
# sq__ft       931 non-null int64
# type         931 non-null object
# sale_date    931 non-null object
# price        931 non-null int64
# latitude     931 non-null float64
# longitude    931 non-null float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 87.4+ KB

# %% [markdown]
# Step-13 Selecting/dropping/renaming columns

# %%
# select columns
Real_Estate_slim = Real_Estate_raw.loc[:,['street', 'city', 'zip', 'sq__ft', 'sale_date', 'price']]

# drop columns
Real_Estate_slim = Real_Estate_slim.drop(['sale_date'], axis=1) # this axis=1 is important!

# rename columns
Real_Estate_slim = Real_Estate_slim.rename(columns={'sq__ft':'Area'})

Real_Estate_slim.head()

# %%
Real_Estate_slim = Real_Estate_raw.loc[:,['street', 'city', 'zip', 'sq__ft', 'sale_date', 'price']]
Real_Estate_slim = Real_Estate_slim.drop(['sale_date'], axis=1)
Real_Estate_slim = Real_Estate_slim.rename(columns={'sq__ft':'Area'})
Real_Estate_slim.head()
# Out:
#              street        city    zip  Area  price
# 0      3526 HIGH ST  SACRAMENTO  95838   836  59222
# 1       51 OMAHA CT  SACRAMENTO  95823  1167  68212
# 2    2796 BRANCH ST  SACRAMENTO  95815   796  68880
# 3  2805 JANETTE WAY  SACRAMENTO  95815   852  69307
# 4   6001 MCMAHON DR  SACRAMENTO  95824   797  81900

# %% [markdown]
# Step-14 Sorting dataframes

# %%
Real_Estate_slim.sort_values('Area', ascending=False).head()
# Out:
#                     street         city    zip  Area   price
# 822         14151 INDIO DR  SLOUGHHOUSE  95683  5822    2000
# 820   9401 BARREL RACER CT       WILTON  95693  4400  884790
# 496  5201 BLOSSOM RANCH DR    ELK GROVE  95757  4303  450000
# 497       3027 PALMATE WAY   SACRAMENTO  95834  4246  452000
# 298       9760 LAZULITE CT    ELK GROVE  95624  3992  460000

# %% [markdown]
# Step-15 Filtering rows with query

# %%
data.query("city == 'sacramento'")
data.head()
# Out:
#              street        city    zip  ...  price   latitude   longitude
# 0      3526 HIGH ST  SACRAMENTO  95838  ...  59222  38.631913 -121.434879
# 1       51 OMAHA CT  SACRAMENTO  95823  ...  68212  38.478902 -121.431028
# 2    2796 BRANCH ST  SACRAMENTO  95815  ...  68880  38.618305 -121.443839
# 3  2805 JANETTE WAY  SACRAMENTO  95815  ...  69307  38.616835 -121.439146
# 4   6001 MCMAHON DR  SACRAMENTO  95824  ...  81900  38.519470 -121.435768
#
# [5 rows x 12 columns]

# %% [markdown]
# Step-16 Importing Janitor as a library

# %%
# !pip install -q pyjanitor
# Out:
#      |████████████████████████████████| 51kB 3.3MB/s
#      |████████████████████████████████| 2.3MB 27.0MB/s

# %%
import janitor

# %% [markdown]
# Step-17 Cleaning up data

# %%
Real_Estate_raw = janitor.clean_names(Real_Estate_raw)

# %% [markdown]
# Step-18 Grouping and aggregating

# %%
data.groupby(['street']).mean().reset_index().head()
# Out:
#                 street      zip  beds  ...     price   latitude   longitude
# 0     1 KENNELFORD CIR  95823.0   3.0  ...  200345.0  38.464520 -121.427606
# 1       10 SEA FOAM CT  95831.0   3.0  ...  415000.0  38.487885 -121.545947
# 2       100 CHELSEA CT  95630.0   3.0  ...  500000.0  38.694350 -121.177259
# 3  100 CRYSTALWOOD CIR  95648.0   0.0  ...    4897.0  38.886091 -121.289744
# 4  100 CRYSTALWOOD WAY  95648.0   0.0  ...    4897.0  38.886282 -121.289706
#
# [5 rows x 8 columns]

# %%
data.groupby(['street']).agg({'beds':'mean', 'baths':'mean'}).reset_index().head()
# Out:
#                 street  beds  baths
# 0     1 KENNELFORD CIR     3      2
# 1       10 SEA FOAM CT     3      3
# 2       100 CHELSEA CT     3      2
# 3  100 CRYSTALWOOD CIR     0      0
# 4  100 CRYSTALWOOD WAY     0      0

# %% [markdown]
# Step-19 Format output with style

# %%
data.style.format({
  'beds': '{:,}'.format,
  'baths': '{:.1f}'.format,
})
# Out:
# <style  type="text/css" >
# </style><table id="T_e8ea03a2_0338_11ea_b02e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >street</th>        <th class="col_heading level0 col1" >city</th>        <th class="col_heading level0 col2" >zip</th>        <th class="col_heading level0 col3" >state</th>        <th class="col_heading level0 col4" >beds</th>        <th class="col_heading level0 col5" >baths</th>        <th class="col_heading level0 col6" >sq__ft</th>        <th class="col_heading level0 col7" >type</th>        <th class="col_heading level0 col8" >sale_date</th>        <th class="col_heading level0 col9" >price</th>        <th class="col_heading level0 col10" >latitude</th>        <th class="col_heading level0 col11" >longitude</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8ea03a2_0338_11ea_b02e_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# Step-21 Scattered Plot Map of Price Vs Sq__Ft

# %%
import matplotlib.pyplot as plt
import pandas as pd
RealEstate = pd.read_csv('RealEstate_CSV.csv', delimiter=';' , nrows=5, skiprows=[10-930])
y = data['sq__ft'];
x = data['price']
plt.xlabel('price(100,000)'); plt.ylabel('sq__ft')
plt.scatter(x,y)

# %% [markdown]
# Step-22 Importing Library and Packages

# %%
# !apt-get -qq install python-cartopy python3-cartopy
import cartopy
# Out:
# Selecting previously unselected package python-pkg-resources.
# (Reading database ... 132684 files and directories currently installed.)
# Preparing to unpack .../0-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-pyshp.
# Preparing to unpack .../1-python-pyshp_1.2.12+ds-1_all.deb ...
# Unpacking python-pyshp (1.2.12+ds-1) ...
# Selecting previously unselected package python-shapely.
# Preparing to unpack .../2-python-shapely_1.6.4-1_amd64.deb ...
# Unpacking python-shapely (1.6.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-cartopy:amd64.
# Preparing to unpack .../4-python-cartopy_0.14.2+dfsg1-2build3_amd64.deb ...
# Unpacking python-cartopy:amd64 (0.14.2+dfsg1-2build3) ...
# ...

# %% [markdown]
# Step-23 Importing further libraries

# %%
# !pip install fiona
# !pip install geopandas
# Import libraries
import pandas as pd
import numpy as np
import math

import geopandas
import json

from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar, NumeralTickFormatter
from bokeh.palettes import brewer

from bokeh.io.doc import curdoc
from bokeh.models import Slider, HoverTool, Select
from bokeh.layouts import widgetbox, row, column
# Out:
# ...
#      |████████████████████████████████| 11.8MB 203kB/s
# ...
#      |████████████████████████████████| 921kB 9.2MB/s
# ...
#      |████████████████████████████████| 10.1MB 33.5MB/s
# ...

# %% [markdown]
# Step-24 Pie Chart of Top 5 highest Area of Household Distribution in CA

# %%
import matplotlib.pyplot as plt

slices = [7,2,2,13]
city = ['sacramento','rio linda','elk grove','lincoln']
cols = ['c','m','r','b']

plt.pie(slices,
        labels=city,
        colors=cols,
        startangle=90,
        shadow= True,
        explode=(0,0.1,0,0),
        autopct='%1.1f%%')

plt.title('City Area Distribution in CA')
plt.show()

# %% [markdown]
# Step-26 Minimum and Maximum

# %%
min(big_array), max(big_array)
np.min(big_array), np.max(big_array)
print(big_array.min(), big_array.max(), big_array.sum())
M = np.random.random((3, 4))
print(M)
M.sum()
M.max(axis=1)
# Out:
# 0.0012003534377302838 0.9996015421245714 472.5347314827689
# [[0.21730223 0.69054439 0.66056624 0.71028931]
#  [0.78082079 0.77680769 0.44091119 0.47509905]
#  [0.68022142 0.31974115 0.34591462 0.85989834]]
# array([0.71028931, 0.78082079, 0.85989834])

# %% [markdown]
# Step-27 What is the Average household price in CA?

# %%
pd.read_csv('RealEstate_CSV.csv')
price = np.array(data['price'])
print(price)
# Out:
# [ 59222  68212  68880  69307  81900  90895  91002  98937 100309 106250
#  106852 107502 108750 113263 120000 121630 122000 122682 123000 124100
#  125000 126640 127281 129000 131200 132000 134555 136500 138750 146250
#  147308 148750 149593 154000 156896 161250 161500 164000 165000 166357
#  166357 168000 170000 173000 174250 174313 178480 178760 179580 181000
#  181872 182587 182716 182750 183200 188741 189000 192067 194000 194818
#  195000 198000 199500 200000 200000 206000 208000 212864 221000 221000
#  223058 227887 231477 234697 235000 236000 236685 237800 240122 242638
#  244000 244500 244960 245918 250000 250000 254200 254200 258000 260000
#  260014 263500 265000 271742 273750 275086 280908 280987 282400 285000
#  287417 291000 292024 297000 297000 298000 299000 304037 311000 315537
#  320000 320000 328360 334150 335750 335750 339500 344250 346210 347029
#  347650 351300 352000 370000 370500 372000 375000 381300 381942 387731
# ...

# %%
print("Mean price:        ",  price.mean())
print("Standard deviation:", price.std())
print("Minimum price:     ",  price.min())
print("Maximum price:     ",  price.max())
# Out:
# Mean price:         239020.04511278195
# Standard deviation: 139592.1798618241
# Minimum price:      1551
# Maximum price:      884790

# %%
print("25th percentile:   ", np.percentile(price, 25))
print("Median:            ", np.median(price))
print("75th percentile:   ", np.percentile(price, 75))
# Out:
# 25th percentile:    150000.0
# Median:             219000.0
# 75th percentile:    304518.5

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # set plot style

# %%
plt.plot()
plt.hist(price)
X = [0,2,4,6,8]
plt.title('Price Distribution of Households in CA')
plt.xlabel('Price of Each Households (Thousands)')
plt.ylabel('number');
plt.show()
